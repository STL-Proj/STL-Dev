# %% [markdown]
# # CN2 - Definition and Plot of the Wavelets

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt
import torch

import os
import sys

# add parent directory to sys.path to import STL package modules
PARENT_DIR = os.path.dirname(os.path.abspath(os.getcwd() + "../../../"))
sys.path.append(PARENT_DIR)
print("Parent directory added to sys.path:", ".../" + PARENT_DIR.split("/")[-1])

# test data directory
DATA_TEST_PATH = PARENT_DIR + "/data" + "/test"
print("Dataset dirctory used:", ".../" + PARENT_DIR.split("/")[-1] + DATA_TEST_PATH.split(PARENT_DIR.split("/")[-1])[-1])


from STL_main.STL_2D_FFT_Torch import STL_2D_FFT_Torch, WaveletOperator2D_FFT_torch
DataClass = STL_2D_FFT_Torch
WaveletOperatorClass = WaveletOperator2D_FFT_torch
from STL_main.torch_backend import _DEFAULT_DEVICE

print("Working on device:", _DEFAULT_DEVICE)
# Out:
# Parent directory added to sys.path: .../c:\Users\Danie\Bureau\STL-Dev
# Dataset dirctory used: .../c:\Users\Danie\Bureau\STL-Dev/data/test
# Working on device: cpu

# %%
# command to auto-reload modules when they are edited (easier for testing and debugging)
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Wavelet Operator class

# %%
# Load some data
data_full = np.load(str(DATA_TEST_PATH) + "/" + "Turb_6.npy")
data = data_full[0]
print("shape data = " + str(data.shape))
print("shape data_full = " + str(data_full.shape))
plt.imshow(data)
# Out:
# shape data = (256, 256)
# shape data_full = (20, 256, 256)

# %%
# Initialization of StlData for MR=False
stl_data = DataClass(array=data)
# Out:
# WARNING: torch.float64 not supported on MPS device. Switching to torch.float32.

# %%
# Construct the wavelet operator
Wave_Op = stl_data.get_wavelet_op()

# %%
# Check the wavelet operator parameters
print("For Wave_Op:")
print("N0 = " + str(Wave_Op.N0))
print("J = " + str(Wave_Op.J))
print("L = " + str(Wave_Op.L))
print("WType = " + str(Wave_Op.WType))

print("Type wavelet_array = " + str(type(Wave_Op.wavelet_array)))
print("Shape wavelet_array = " + str(Wave_Op.wavelet_array.shape))

print("Type wavelet_array_MR = " + str(type(Wave_Op.wavelet_array_MR)))
print("dg_max = " + str(Wave_Op.dg_max))
print("j_to_dg = " + str(Wave_Op.j_to_dg))

# Fix J and L values
J = Wave_Op.J
L = Wave_Op.L
# Out:
# For Wave_Op:
# N0 = torch.Size([256, 256])
# J = 6
# L = 4
# WType = Bump-Steerable
# Type wavelet_array = <class 'torch.Tensor'>
# Shape wavelet_array = torch.Size([6, 4, 256, 256])
# Type wavelet_array_MR = <class 'list'>
# dg_max = 4
# j_to_dg = [0, 1, 2, 3, 4, 4]

# %%
# Check the wavelet wavelet_array_MR structure
print("Len of wavelet_array_MR = " + str(len(Wave_Op.wavelet_array_MR)))
for j in range(J):
    print("Shape wavelet_array_MR for j=" + str(j) + " is " + str(Wave_Op.wavelet_array_MR[j].shape))
# Out:
# Len of wavelet_array_MR = 6
# Shape wavelet_array_MR for j=0 is torch.Size([4, 256, 256])
# Shape wavelet_array_MR for j=1 is torch.Size([4, 128, 128])
# Shape wavelet_array_MR for j=2 is torch.Size([4, 64, 64])
# Shape wavelet_array_MR for j=3 is torch.Size([4, 32, 32])
# Shape wavelet_array_MR for j=4 is torch.Size([4, 16, 16])
# Shape wavelet_array_MR for j=5 is torch.Size([4, 16, 16])

# %% [markdown]
# ## Plot in Fourier and real space

# %%
# Plot the wavelet set in Fourier
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(Wave_Op.wavelet_array[j, l].cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot the wavelet set in Fourier, with fftshift
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(torch.fft.fftshift(Wave_Op.wavelet_array[j, l], dim=(-2,-1)).cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot the sum and quadratic sum of the wavelets

# Plot the wavelet set in Fourier, with fftshift
fig, axs = plt.subplots(1, 2, figsize=(8, 16))

im = axs[0].imshow(torch.fft.fftshift(Wave_Op.wavelet_array.sum(dim=(0,1)), dim=(-2,-1)).cpu().numpy())
axs[0].axis('off')
axs[0].set_title('Sum of wavelets')
plt.colorbar(im, fraction=0.046, pad=0.04)
im = axs[1].imshow(torch.fft.fftshift((Wave_Op.wavelet_array**2).sum(dim=(0,1)), dim=(-2,-1)).cpu().numpy())
axs[1].axis('off')
axs[1].set_title('Quadratic sum of wavelets')
plt.colorbar(im, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# %%
# Plot the wavelet set in real space, with fftshift
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(torch.fft.fftshift(torch.fft.fft2(Wave_Op.wavelet_array[j, l]).real, dim=(-2,-1)).cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot the MR wavelet set in Fourier, with fftshift
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(torch.fft.fftshift(Wave_Op.wavelet_array_MR[j][l], 
                                     dim=(-2,-1)).cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot the MR wavelet set in real space, with fftshift
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(torch.fft.fftshift(
            torch.fft.ifft2(Wave_Op.wavelet_array_MR[j][l]).imag,
            dim=(-2,-1)).cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Wavelet Operator and plot with non-standard sizes

# %%
# Initialization of StlData for MR=False
stl_data2 = DataClass(data[:187, :249])
# Out:
# WARNING: torch.float64 not supported on MPS device. Switching to torch.float32.

# %%
# Construct the wavelet operator
Wave_Op = stl_data2.get_wavelet_op()

# %%
# Check the wavelet operator parameters
print("For Wave_Op:")
print("N0 = " + str(Wave_Op.N0))
print("J = " + str(Wave_Op.J))
print("L = " + str(Wave_Op.L))
print("WType = " + str(Wave_Op.WType))
print("Type wavelet_array = " + str(type(Wave_Op.wavelet_array)))
print("Shape wavelet_array = " + str(Wave_Op.wavelet_array.shape))
print("Type wavelet_array_MR = " + str(type(Wave_Op.wavelet_array_MR)))
print("dg_max = " + str(Wave_Op.dg_max))
print("j_to_dg = " + str(Wave_Op.j_to_dg))

# Fix J and L values
J = Wave_Op.J
L = Wave_Op.L
# Out:
# For Wave_Op:
# N0 = torch.Size([187, 249])
# J = 5
# L = 4
# WType = Bump-Steerable
# Type wavelet_array = <class 'torch.Tensor'>
# Shape wavelet_array = torch.Size([5, 4, 187, 249])
# Type wavelet_array_MR = <class 'list'>
# dg_max = 3
# j_to_dg = [0, 1, 2, 3, 3]

# %%
# Check the wavelet wavelet_array_MR structure
print("Len of wavelet_array_MR = " + str(len(Wave_Op.wavelet_array_MR)))
for j in range(J):
    print("Shape wavelet_array_MR for j=" + str(j) + " is " + str(Wave_Op.wavelet_array_MR[j].shape))
# Out:
# Len of wavelet_array_MR = 5
# Shape wavelet_array_MR for j=0 is torch.Size([4, 186, 248])
# Shape wavelet_array_MR for j=1 is torch.Size([4, 92, 124])
# Shape wavelet_array_MR for j=2 is torch.Size([4, 46, 62])
# Shape wavelet_array_MR for j=3 is torch.Size([4, 22, 30])
# Shape wavelet_array_MR for j=4 is torch.Size([4, 22, 30])

# %%
# Plot the wavelet set in Fourier, with fftshift
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(torch.fft.fftshift(Wave_Op.wavelet_array[j, l], 
                                     dim=(-2,-1)).cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot the wavelet set in real space, with fftshift
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(torch.fft.fftshift(
            torch.fft.fft2(Wave_Op.wavelet_array[j, l]).real, 
            dim=(-2,-1)).cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot the MR wavelet set in Fourier, with fftshift
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(torch.fft.fftshift(Wave_Op.wavelet_array_MR[j][l], 
                                     dim=(-2,-1)).cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot the MR wavelet set in real space, with fftshift
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(torch.fft.fftshift(
            torch.fft.fft2(Wave_Op.wavelet_array_MR[j][l]).real, 
            dim=(-2,-1)).cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analytic Bump Steerable Wavelet Bank

# %%
data = np.load(str(DATA_TEST_PATH) + "/" + "Turb_6.npy")[0]

stl_data = DataClass(array=data)    
Wave_Op = stl_data.get_wavelet_op()

xi0 = 0.5 * torch.pi 
smooth_nyquist = False
J = Wave_Op.J
L = Wave_Op.L
low_pass_filter, bump_steerable_bank = Wave_Op.analytic_bump_steerable_bank(
    J=J,
    L=L,
    size=Wave_Op.N0,
    xi0=xi0,
    smooth_nyquist=smooth_nyquist
)

# %%
# Plot the wavelet set in Fourier
fig, axs = plt.subplots(J, L, figsize=(2 * L, 2 * J))
axs = axs.reshape(J, L)

for j in range(J):
    for l in range(L):
        ax = axs[j, l]
        ax.imshow(torch.fft.fftshift(bump_steerable_bank[j, l], dim=(-2,-1)).cpu().numpy())
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# $$A(\boldsymbol{\omega}) = |L_0(\boldsymbol{\omega})|^2 + \frac{1}{2} \sum_{j=1}^{J-1} \sum_{l=0}^{L-1} \left( |\Psi_{j,l}(\boldsymbol{\omega})|^2 + |\Psi_{j,l}(-\boldsymbol{\omega})|^2 \right)$$

# %%
# Spectral coverage function A(omega)
bump_mirrored = torch.flip(bump_steerable_bank, dims=(-2, -1))

A = (
    low_pass_filter.pow(2)
    + 0.5 * (bump_steerable_bank.pow(2) + bump_mirrored.pow(2)).sum(dim=(0, 1))
)

# Absolute error with respect to 1
error = A - 1.0

error_shifted = torch.fft.fftshift(
    error, dim=(-2, -1)
).cpu().numpy()

# %%
from matplotlib import colors
import numpy as np

class MidpointNormalize(colors.Normalize):
    def __init__(self, midpoint=0, acceptance=0.1):
        self.midpoint = midpoint
        self.amplitude = 5 * acceptance

        super().__init__(
            vmin=midpoint - self.amplitude,
            vmax=midpoint + self.amplitude,
        )

    def __call__(self, value, clip=None):
        x = [
            self.midpoint - self.amplitude,
            self.midpoint,
            self.midpoint + self.amplitude,
        ]

        y = [0, 0.5, 1]

        return np.ma.masked_array(np.interp(value, x, y))
    

plt.imshow(
    error_shifted, cmap='bwr', norm=MidpointNormalize(midpoint=0)
)

plt.title(r'Error $A(\boldsymbol{\omega}) - 1$')
plt.gca().xaxis.set_visible(False)
plt.gca().yaxis.set_visible(False)
plt.colorbar()

# %%
# Center of the frequency domain
H, W = torch.fft.fftshift(A, dim=(-2, -1)).shape
A_ifted = torch.fft.fftshift(A, dim=(-2, -1))
cy, cx = H // 2, W // 2

# Radial profile: horizontal cut through the center
radial_profile = A_ifted[cy, cx:].cpu().numpy()

# Normalized radial coordinate
r = torch.linspace(0, torch.pi, radial_profile.shape[0]).cpu().numpy()

plt.figure(figsize=(8, 4))

plt.plot(r, radial_profile)

# Acceptance interval
plt.axhline(1.0, linestyle='--', label=r'Target $A=1$')
plt.axhline(0.9, linestyle=':', label=r'Acceptance bounds')
plt.axhline(1.1, linestyle=':')

plt.xlabel(r'Radial frequency $|\boldsymbol{\omega}|$')
plt.ylabel(r'$A(|\boldsymbol{\omega}|)$')
plt.title(r'Radial profile of the spectral coverage $A(\boldsymbol{\omega})$')

plt.xticks(
    [0, np.pi/8, np.pi/4, np.pi/2, np.pi],
    [r'$0$', r'$\frac{\pi}{8}$', r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\pi$']
)

plt.ylim(0)

plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We verify **energy conservation** by checking whether the energy of the input signal $x$, measured by its squared $L^2$ norm, can be decomposed as the sum of the energies captured by the wavelets in the filter bank:
#
# $$
# \boxed{
# \|x\|_2^2
# \approx
# \sum_{j,\lambda}
# \left\|
# x * \phi_{j,\lambda}
# \right\|_2^2
# }
# $$
#
# In other words, the total energy of $x$ should be recovered by summing the energies of its convolutions with all the wavelets across scales $j$ and orientations $\lambda$.
#
# We use **white noise** as the input signal $x$. This is important because, for a structured signal, the energy tends to be concentrated around the center of the Fourier domain. This would make it difficult to assess whether the wavelets at smaller scales correctly recover the energy.

# %%
# Generate a white noise image
x = torch.randn(
    stl_data.N0,
    device=stl_data.device,
    dtype=stl_data.dtype,
)

# Fourier transform of the input signal
x_hat = torch.fft.fft2(x, norm="ortho")


# ============================================================
# Fourier disk mask
# ============================================================

Nx, Ny = x.shape

freq_x = 2 * torch.pi * torch.fft.fftfreq(
    Nx,
    device=stl_data.device,
    dtype=stl_data.dtype,
)

freq_y = 2 * torch.pi * torch.fft.fftfreq(
    Ny,
    device=stl_data.device,
    dtype=stl_data.dtype,
)

omega_x, omega_y = torch.meshgrid(
    freq_x,
    freq_y,
    indexing="ij",
)

disk_mask = (
    torch.sqrt(omega_x**2 + omega_y**2) <= torch.pi
)


# ============================================================
# Energy conservation
# ============================================================

for name, mask in [
    ("Full Fourier domain", None),
    ("Fourier disk |ω| ≤ π", disk_mask),
]:

    # Apply Fourier mask
    if mask is None:
        x_hat_masked = x_hat
    else:
        x_hat_masked = x_hat * mask

    # Input energy
    input_energy = torch.sum(
        torch.abs(x_hat_masked) ** 2
    )

    # Wavelet energy
    wavelet_coeffs_hat = (
        bump_steerable_bank
        * x_hat_masked.unsqueeze(0).unsqueeze(0)
    )

    wavelet_energy = torch.sum(
        torch.abs(wavelet_coeffs_hat) ** 2
    )

    # Low-pass energy
    low_pass_energy = torch.sum(
        torch.abs(low_pass_filter * x_hat_masked) ** 2
    )

    # Total projected energy
    projected_energy = (
        wavelet_energy + low_pass_energy
    )

    # Relative error
    relative_error = (
        100
        * torch.abs(input_energy - projected_energy)
        / input_energy
    )

    print(f"\n{name}")
    print(f"Input energy:       {input_energy.item():.6f}")
    print(f"Projected energy:   {projected_energy.item():.6f}")
    print(f"Relative error (%): {relative_error.item():.6f}")
# Out:
# Full Fourier domain
# Input energy:       65231.729050
# Projected energy:   62025.974594
# Relative error (%): 4.914410
#
# Fourier disk |ω| ≤ π
# Input energy:       51243.244911
# Projected energy:   49200.273447
# Relative error (%): 3.986811
