# %%
import sys
import os
# Get parent of current working directory
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
# Add it to sys.path
sys.path.insert(0, parent_dir)

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from StlData import StlData
import ST_Operator as STO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import matplotlib.pyplot as plt
#       4 from StlData import StlData
# ----> 5 import ST_Operator as STO
#
# File ~/Desktop/STL_development/STL_dev/STL_main/ST_Operator.py:12
#      10 from WaveletTransform import Wavelet_Operator
#      11 from ST_Statistics import ST_Statistics
# ---> 12 import bk # from_numpy, zeros, dim, shape, nan
#      14 ###############################################################################
#      15 ###############################################################################
#      17 class ST_Operator:
#
# ModuleNotFoundError: No module named 'bk'
